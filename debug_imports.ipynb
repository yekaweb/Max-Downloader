# %% [markdown]
# # Import Debug Notebook
#
# Test if `from database.repositories import UserRepository` and other repository imports work correctly in the repository environment.

# %%
import sys
sys.path.insert(0, '/home/reza/Max-Downloader')

try:
    from database.repositories import UserRepository
    print('UserRepository imported successfully:', UserRepository)
except Exception as e:
    print('UserRepository import failed:', type(e).__name__, e)

try:
    from database.repositories.user_repo import UserRepository as UR
    print('Direct import succeeded:', UR)
except Exception as e:
    print('Direct user_repo import failed:', type(e).__name__, e)

try:
    from database.models import User
    print('User model imported successfully:', User)
except Exception as e:
    print('User model import failed:', type(e).__name__, e)
